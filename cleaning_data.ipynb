# %%
import warnings; warnings.simplefilter("ignore")

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
wb_breaches = pd.ExcelFile(r"Ritu:\Desktop\data_breaches.xlsx")

sheet_1 = pd.read_excel(r"Ritu:\Desktop\data_breaches.xlsx", sheetname = 0)
sheet_2 = pd.read_excel(r"Ritu:\Desktop\data_breaches.xlsx", sheetname = 1)
sheet_3 = pd.read_excel(r"Ritu:\Desktop\data_breaches.xlsx", sheetname = 2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-17e008b525b6> in <module>()
# ----> 1 wb_breaches = pd.ExcelFile(r"Ritu:\Desktop\data_breaches.xlsx")
#       2
#       3 sheet_1 = pd.read_excel(r"Ritu:\Desktop\data_breaches.xlsx", sheetname = 0)
#       4 sheet_2 = pd.read_excel(r"Ritu:\Desktop\data_breaches.xlsx", sheetname = 1)
#       5 sheet_3 = pd.read_excel(r"Ritu:\Desktop\data_breaches.xlsx", sheetname = 2)
#
# /usr/local/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     258             self.book = xlrd.open_workbook(file_contents=data)
#     259         elif isinstance(io, compat.string_types):
# --> 260             self.book = xlrd.open_workbook(io)
#     261         else:
#     262             raise ValueError('Must explicitly set engine if not passing in'
#
# ...

# %%
data_breaches = pd.ExcelFile("data_breaches.xlsx")

# %%
sheet_1 = pd.read_excel("data_breaches.xlsx", sheetname = 0)
sheet_2 = pd.read_excel("data_breaches.xlsx", sheetname = 1)
sheet_3 = pd.read_excel("data_breaches.xlsx", sheetname = 2)

# %%
read_sheets_name = data_breaches.sheet_names
print(read_sheets_name)
# Out:
# ['2017 update', 'Jan 2015 update', 'July 2013 update (old)']

# %%
sheet_1
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
data_copy = data_breaches.copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-4bc07e2e3524> in <module>()
# ----> 1 data_copy = data_breaches.copy()
#
# AttributeError: 'ExcelFile' object has no attribute 'copy'

# %%
import copy

# %%
data_copy = data_breaches.copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-4bc07e2e3524> in <module>()
# ----> 1 data_copy = data_breaches.copy()
#
# AttributeError: 'ExcelFile' object has no attribute 'copy'

# %%
data_copy = copy.copy(data_breaches)

# %%
del pd.UNUSED
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-e290d4e66327> in <module>()
# ----> 1 del pd.UNUSED
#
# AttributeError: UNUSED

# %%
data_breaches.drop(data_breaches.column_name = 0)
# Out:
#   File "<ipython-input-14-aaa5388e2011>", line 1
#     data_breaches.drop(data_breaches.column_name = 0)
#                       ^
# SyntaxError: keyword can't be an expression

# %%
data_breaches.drop(data_breaches.columns[[0]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-56f89b62d17d> in <module>()
# ----> 1 data_breaches.drop(data_breaches.columns[[0]], axis=1)
#
# AttributeError: 'ExcelFile' object has no attribute 'drop'

# %%
import pandas as pd

# %%
data_breaches.drop(data_breaches.columns[[0]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-56f89b62d17d> in <module>()
# ----> 1 data_breaches.drop(data_breaches.columns[[0]], axis=1)
#
# AttributeError: 'ExcelFile' object has no attribute 'drop'

# %%
sheet_1 = sheet_1.dropna(axis=1, how='all')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-e42741b49bb4> in <module>()
# ----> 1 sheet_1 = sheet_1.dropna(axis=1, how='all')
#
# AttributeError: 'function' object has no attribute 'dropna'

# %%
sheet_1 = sheet_1.drop(axis=1, how='all')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-8409d410eacf> in <module>()
# ----> 1 sheet_1 = sheet_1.drop(axis=1, how='all')
#
# AttributeError: 'function' object has no attribute 'drop'
